# %%
# passivate/activate method
# https://www.salabim.org/manual/Modelling.html#a-bank-example

import salabim as sim


class CarGenerator(sim.Component):
    def setup(self):
        self.mode.monitor(False)
        self.status.monitor(False) # added 17 nov, salabim team tip

    def process(self):
        while True:
            Car(name="Car")
            self.hold(iat_distr.sample())


class Car(sim.Component):
    def setup(self):
        self.mode.monitor(False)
        self.status.monitor(False) # added 17 nov, salabim team tip

    def process(self):
        self.enter(waitingline)
        for ChargingStation in ChargingStations:
            if ChargingStation.ispassive():
                ChargingStation.activate()
                break  # activate at most one charging station
        self.passivate()


class ChargingStation(sim.Component):
    def setup(self):
        self.mode.monitor(False)
        self.status.monitor(False)  # added 17 nov, salabim team tip

    def process(self):
        while True:
            while len(waitingline) == 0:
                self.passivate()
            self.car = waitingline.pop()
            self.hold(srv_distr.sample())
            self.car.activate()


N_STATION = 1
iat_distr = sim.Exponential(60 / 40)
srv_distr = sim.Exponential(60 / 50)

# https://www.salabim.org/manual/Reference.html#environment
app = sim.App(
    trace=False,  # defines whether to trace or not
    random_seed="*",  # if “*”, a purely random value (based on the current time)
    time_unit="minutes",  # defines the time unit used in the simulation
    name="Charging Station",  # name of the simulation
    do_reset=True,  # defines whether to reset the simulation when the run method is called
    yieldless=True,  # defines whether the simulation is yieldless or not
)

# Instantiate and activate the client generator
CarGenerator(name="Electric Cars Generator")

# Create Queue and set monitor to stats_only
waitingline = sim.Queue(name="Waiting Cars", monitor=False)
waitingline.length_of_stay.monitor(value=False)
# waitingline.length_of_stay.reset_monitors(stats_only=True)

# Instantiate the servers, list comprehension but only 1 server
ChargingStations = [ChargingStation() for _ in range(N_STATION)]

# Execute Simulation
app.run(till=sim.inf)

# Print statistics
waitingline.length_of_stay.print_statistics()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14166/1978767066.py in ?()
# ---> 72 # passivate/activate method
#      73 # https://www.salabim.org/manual/Modelling.html#a-bank-example
#      74
#      75 import salabim as sim
#
# ~/miniforge3/envs/env_sim/lib/python3.9/site-packages/salabim/salabim.py in ?(self, duration, till, priority, urgent, cap_now)
#   26215         while self.running:
#   26216             if self._animate and not self._blind_animation:
#   26217                 self.do_simulate_and_animate()
#   26218             else:
# > 26219                 self.do_simulate()
#   26220         if self.stopped:
#   26221             self.quit()
#   26222             if self._video:
#
# ~/miniforge3/envs/env_sim/lib/python3.9/site-packages/salabim/salabim.py in ?(self)
#   26230         else:
#   26231             while g.in_draw:
#   26232                 pass
#   26233             while self.running and not self._animate:
# > 26234                 self.step()
#
# ~/miniforge3/envs/env_sim/lib/python3.9/site-packages/salabim/salabim.py in ?(self)
#   24143                     self._terminate(c)
#   24144         except Exception as e:
#   24145             if self._animate:
#   24146                 self.an_quit()
# > 24147             raise e
#
# /tmp/ipykernel_14166/1978767066.py in ?(self)
#      23     def process(self):
# ---> 24         self.enter(waitingline)
#      25         for ChargingStation in ChargingStations:
#      26             if ChargingStation.ispassive():
#      27                 ChargingStation.activate()
#
# ~/miniforge3/envs/env_sim/lib/python3.9/site-packages/salabim/salabim.py in ?(self, q)
#    9366         or 0 if queue is empty
#    9367         """
#    9368         self._checknotinqueue(q)
#    9369         priority = q._tail.predecessor.priority
# -> 9370         Qmember().insert_in_front_of(q._tail, self, q, priority)
#    9371         return self
#
# ~/miniforge3/envs/env_sim/lib/python3.9/site-packages/salabim/salabim.py in ?(self, m2, c, q, priority)
#    4202         c._qmembers[q] = self
#    4203         if q.env._trace:
#    4204             if not q._isinternal:
#    4205                 q.env.print_trace("", "", c.name(), "enter " + q.name())
# -> 4206         q.length.tally(q._length)
#    4207         q.number_of_arrivals += 1
#    4208         if isinstance(q, Store):
#    4209             store = q
#
# KeyboardInterrupt:
